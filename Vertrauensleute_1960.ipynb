# %%
import pandas as pd
# Out:
# /tmp/ipykernel_24622/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import folium

# %%
import branca

# %%
from branca.element import Template, MacroElement

# %%
m = folium.Map(location=[54.19500881461512, 12.698799397903633], zoom_start=8)

# %%
#Angaben entnommen aus: O.A.: Zusammenstellung der zur Zeit tätigen ehrenamtlichen Vertrauensleute, S. 14–15, in: Mitteilungen an die ehrenamtlichen Vertrauensleute des Instituts für Denkmalpflege Schwerin, Nr. 9 (4. Quartal 1960).
folium.Marker(
    location=[54.1005374008696, 11.894265792407982],
    popup="Lutz Elbrecht",
    tooltip="Kreis Doberan",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.58493301459101, 13.102752660216234],
    popup="Karl Ebbinghaus",
    tooltip="Kreis Hiddensee",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.259341715516186, 12.473611846791664],
    popup="Ernst Garduhn",
    tooltip="Kreis Ribnitz-Damgarten",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.09369141747155, 13.40418209240455],
    popup="Paul Schumacher",
    tooltip="Kreis Greifswald",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.8533193033017, 10.927992794278037],
    popup="Erwin Werner",
    tooltip="Kreis Grevesmühlen",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.087808512735855, 12.143027133528104],
    popup="Georg Martens",
    tooltip="Kreis Rostock-Stadt",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.312869162760265, 13.087840220233398],
    popup="Käthe Rieck",
    tooltip="Kreis Stralsund",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.888850105013155, 11.460380992030684],
    popup="Friedrich Wöhlke",
    tooltip="Kreis Wismar-Land",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[54.050833696840485, 14.003969827275009],
    popup="Kurt Kracht",
    tooltip="Kreis Wolgast",
    icon=folium.Icon(color="orange", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.83737428697251, 11.996147858267815],
    popup="Dr. Hans Vorbeck",
    tooltip="Kreis Bützow",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.70482602196261, 11.106748172488082],
    popup="Gerd Behrend",
    tooltip="Kreis Gadebusch",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.79070054320901, 12.170183705360357],
    popup="Rudolf Pilz",
    tooltip="Kreis Güstrow",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.51234554312456, 11.077187207239634],
    popup="Paul Francke",
    tooltip="Kreis Hagenow",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.33457685526698, 11.494111469206734],
    popup="Hans-Joachim Ehlers",
    tooltip="Kreis Ludwigslust",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.43155428981014, 11.852017995490407],
    popup="Dr. Fritz Kühl",
    tooltip="Kreis Parchim",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.0719391726059, 11.858463328907222],
    popup="Albert Hoppe",
    tooltip="Kreis Perleberg",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.60913532920359, 11.41929144636119],
    popup="Hans-Heinrich Leopoldi",
    tooltip="Kreis Schwerin-Stadt",
    icon=folium.Icon(color="red", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.76174271565606, 13.103562662837495],
    popup="Dr. Günther Kehnscherper",
    tooltip="Kreis Altentreptow",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.84999469454407, 13.686649922472851],
    popup="Kurt Buchholz",
    tooltip="Kreis Anklam",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.900447903633165, 13.022978661012521],
    popup="Dipl.-Arch. J. Bauckmeier",
    tooltip="Kreis Demmin",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.739201304705844, 12.76339113435255],
    popup="Franz Fell",
    tooltip="Kreis Malchin",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.55210357619386, 13.262465919778034],
    popup="Dipl.-Ing. Erich Brückner",
    tooltip="Kreis Neubrandenburg",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.58058941883427, 13.938465465205153],
    popup="Dr. Erich Tertsch",
    tooltip="Kreis Pasewalk",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.11697037324702, 13.508913317556248],
    popup="Fr. Scholz-Padiera",
    tooltip="Kreis Templin",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.32060663896241, 13.858430837583356],
    popup="Alfred Hinrichs",
    tooltip="Kreis Prenzlau",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.7692258544029, 12.5781331796641],
    popup="Louis Hoeppner",
    tooltip="Kreis Teterow",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

folium.Marker(
    location=[53.502648845398504, 13.08537598199292],
    popup="Dipl.-Ing. E. A. Schröder",
    tooltip="Kreis Waren",
    icon=folium.Icon(color="purple", icon="user", prefix="fa")
).add_to(m)

# %%
template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>
     
<div class='legend-title'>Farblegende</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:orange;'></span>Bezirk Rostock</li>
    <li><span style='background:red;'></span>Bezirk Schwerin</li>
    <li><span style='background:purple;'></span>Bezirk Neubrandenburg</li>
  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)


m.get_root().add_child(macro)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
